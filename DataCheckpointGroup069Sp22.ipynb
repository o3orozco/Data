# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# # Names
#
# - Rylan Keolanui
# - Lauren Himpelmann
# - Jasmine Shafie
# - Maxim Kondrashuk
# - Ozzie Orozco

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# Is there a relationship over the last decade between the tone of the news articles from CNN and Fox and the divisiveness and radicalization of the Americans, who read articles from CNN and Fox, along the party lines (Democrat and Republican)?

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# 1. American politcal affiliation
# - https://news.gallup.com/poll/15370/party-affiliation.aspx
# - 384 observations
# - This data set contains American political affiliation (Republicans, Indepedents, Democrats) from 2004 to 2022 polled weekly/biweekly. Will be using this data set to measure the radicalization of Americans.
#
# 2. CNN news articles
# - https://www.kaggle.com/datasets/hadasu92/cnn-articles-after-basic-cleaning
# - 4076
# - This data set contains CNN news articles (headline, keywords, and the article itself) from 2011 to 2022. We will use this data set to interpret the sentiment of the articles over the years in relation to the politcal affiliation.
#
#
# At this point we are only using the Pandas package. Later on we will be using other packages for the EDA.

# %% [markdown]
# # Setup

# %%
## YOUR CODE HERE
import pandas as pd
#data = pd.read_stata("/Users/maximkondrashuk/Downloads/GSS_stata/gss7221_r1b.dta")
#data.to_csv('https://drive.google.com/file/d/1qea12rzjPiAS_WxOWhXAM5t4taRlFaP3/view?usp=sharing')
#cnn = pd.read_json("https://github.com/maximk-8/cogs108_data/blob/main/convertcsv.json")
#cnn
political_views = pd.read_csv("https://raw.githubusercontent.com/maximk-8/cogs108_data/main/data.txt")
print(political_views)
cnn = pd.read_csv("https://raw.githubusercontent.com/maximk-8/cogs108_data/main/CNN_Articels_clean.csv")
cnn
# Out:
#                   Date  Republican  Independent  Democrat
# 0        2022 Mar 1-18          28           40        30
# 1        2022 Feb 1-17          26           42        29
# 2        2022 Jan 3-16          24           46        28
# 3        2021 Dec 1-16          26           42        30
# 4        2021 Nov 1-16          31           41        27
# ..                 ...         ...          ...       ...
# 379       2004 Feb 6-8          33           36        30
# 380  2004 Jan 29-Feb 1          31           35        33
# 381     2004 Jan 12-15          32           33        34
# 382      2004 Jan 9-11          33           35        31
# 383       2004 Jan 2-5          32           40        28
#
# [384 rows x 4 columns]
#       Index                                             Author  \
# 0         0                                 Jacopo Prisco, CNN
# 1         2                              Stephanie Bailey, CNN
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The "American political affiliation" data set is already cleaned because we compiled the data ourselves from the website. There are no missing or irrelevant values. To get the data into a usable format we copied and pasted the values and then seperated the spaces with commas to create a CSV file.
#
# For the "CNN news articles" we are only interested in the articles in the "politics" category. Also we will be checking for NaN. We did not have to do anything to the data to get it into a usable format it was already done for us.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

cnn = cnn.loc[cnn['Category'] == "politics"]
print(cnn.isnull().values.any())
cnn
# Out:
# False
#      Index                                             Author  \
# 163    214                       Analysis by Daniel Dale, CNN
# 164    216                Daniel Dale and Marshall Cohen, CNN
# 165    218                       Analysis by Daniel Dale, CNN
# 166    220  Terence Burlij, Melissa Holzberg DePalo and Et...
# 167    221                      Analysis by Ronald Brownstein
# ..     ...                                                ...
# 760   1375                                   Casey Tolan, CNN
# 761   1377      Rob Kuznia, Curt Devine and Drew Griffin, CNN
# 762   1379  Curt Devine, Majlie de Puy Kamp and Scott Glov...
# 763   1381  Casey Tolan, Curt Devine, Drew Griffin and Sco...
# 765   1385               Curt Devine and Scott Bronstein, CNN
#
#           Date published  Category   Section  \
# 163  2022-01-20 12:00:17  politics  politics
# 164  2022-01-04 23:12:55  politics  politics
# 165  2021-03-03 01:33:41  politics  politics
# ...

# %% [markdown]
# After wrangling the CNN data it is now clean because all articles are from the politics category and there are no NaN's in the data set.
